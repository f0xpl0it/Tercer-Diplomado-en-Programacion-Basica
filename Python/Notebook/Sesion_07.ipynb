# %% [markdown]
# <table style="width: 100%; background-color: transparent;">
#     <tr>
#         <!-- Columna del texto alineado al centro -->
#         <td width="75%" style="text-align: center; vertical-align: middle; padding-left: 50px;">
#             <!-- Contenedor del bloque de texto centrado -->
#             <div style="display: inline-block;">
#                 <span style="display: block; font-size: 70px; font-weight: bold; color: #f25625;">
#                     Introduction to Python
#                 </span>
#                 <span style="display: block; font-size: 50px; font-weight: bold; color: #f25625;">
#                     Lecture Notes
#                 </span>
#                 <span style="display: block; font-size: 30px; font-weight: bold; color: #f25625;">
#                     September 2025
#                 </span>
#             </div>
#         </td>
#         <!-- Columna de la imagen alineada a la derecha -->
#         <td width="25%" style="text-align: right; vertical-align: middle; padding-right: 50px;">
#             <img
#                 src="data:image/png;base64,..."
#                 width="300"
#                 style="display: block; margin-left: auto;"
#             />
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <p style="text-align:right; font-style: italic; font-size: 20px;">
#   <span style="font-weight: bold;">Autor:</span> Michael Steven Paucar Rojas
# </p>

# %% [markdown]
# <table style="width: 100%; font-size: 20px;font-weight: bold;">
#   <tr>
#     <td style="text-align: left;">
#       Session - 7
#     </td>
#     <td style="text-align: right;">
#       📅 2025/10/10
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## Contents
#
# 1. [Python Functions](#1)
#    1. [Functions](#1.1)
#    2. [Creating a Function](#1.2)
#    3. [Calling a Function](#1.3)
#    4. [Function Names](#1.4)
#    5. [Why Use Functions?](#1.5)
#    6. [Return Values](#1.6)
#    7. [The pass Statement](#1.7)
# 2. [Python Arguments](#2)
#    1. [Arguments](#2.1)
#    2. [Parameters vs Arguments](#2.2)
#    3. [Number of Arguments](#2.3)
#    4. [Default Parameter Values](#2.4)
#    5. [Keyword Arguments](#2.5)
#    6. [Positional Arguments](#2.6)
#    7. [Mixing Positional and Keyword Arguments](#2.7)
#    8. [Passing Different Data Types](#2.8)
#    9. [Return Values](#2.9)
#    10. [Returning Different Data Types](#2.10)
#    11. [Positional-Only Arguments](#2.11)
#    12. [Keyword-Only Arguments](#2.12)
#    13. [Combining Positional-Only and Keyword-Only](#2.13)
# 3. [Python \*args and  \*\*kwargs](#3)
#    1. [*args and **kwargs](#3.1)
#    2. [Arbitrary Arguments - *args](#3.2)
#    3. [What is *args?](#3.3)
#    4. [Using *args with Regular Arguments](#3.4)
#    5. [Practical Example with *args](#3.5)
#    6. [Arbitrary Keyword Arguments - **kwargs](#3.6)
#    7. [What is **kwargs?](#3.7)
#    8. [Using **kwargs with Regular Arguments](#3.8)
#    9. [Combining *args and **kwargs](#3.9)
#    10. [Unpacking Arguments](#3.10)
# 4. [Challenge #10](#4)
# 5. [Python Scope](#5)
#    1. [Scope](#5.1)
#    2. [Local Scope](#5.2)
#    3. [Global Scope](#5.3)
#    4. [Global Keyword](#5.4)
#    5. [Nonlocal Keyword](#5.5)
#    6. [The LEGB Rule](#5.6)
# 6. [Python Decorators](#6)
#    1. [Basic Decorator](#6.1)
#    2. [Multiple Decorator Calls](#6.2)
#    3. [Arguments in the Decorated Function](#6.3)
#    4. [*args and **kwargs](#6.4)
#    5. [Decorator With Arguments](#6.5)
#    6. [Multiple Decorators](#6.6)
#    7. [Preserving Function Metadata](#6.7)
# 7. [Python Lambda](#7)
#    1. [Lambda Functions](#7.1)
#    2. [Syntax](#7.2)
#    3. [Why Use Lambda Functions?](#7.3)

# %% [markdown]
# # <center>**Python Functions**

# %% [markdown]
# # **Functions**
# ---

# %% [markdown]
# A function is a block of code which only runs when it is called.
#
# A function can return data as a result.
#
# A function helps avoiding code repetition.

# %% [markdown]
# ## 🔹 **Creating a Function**

# %% [markdown]
# In Python, a function is defined using the `def` keyword, followed by a function name and parentheses:

# %% [markdown]
# #### Example

# %%
def greet():
  print("Hello from a function")

# %% [markdown]
# This creates a function named `my_function` that prints "Hello!" when called.

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# The code inside the function must be indented. Python uses indentation to define code blocks.

# %% [markdown]
# ## 🔹 **Calling a Function**

# %% [markdown]
# To call a function, write its name followed by parentheses:

# %% [markdown]
# #### Example

# %%
def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %% [markdown]
# You can call the same function multiple times:

# %% [markdown]
# #### Example

# %%
def my_function():
  print("Hello from a function")

my_function()
my_function()
my_function()
# Out:
# Hello from a function
# Hello from a function
# Hello from a function

# %% [markdown]
# ## 🔹 **Function Names**

# %% [markdown]
# Function names follow the same rules as variable names in Python:
#
# * A function name must start with a letter or underscore
# * A function name can only contain letters, numbers, and underscores
# * Function names are case-sensitive (`myFunction` and `myfunction` are different)

# %% [markdown]
# #### Example

# %% [markdown]
# Valid function names:

# %%
calculate_sum()
_private_function()
myFunction2()

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# It's good practice to use descriptive names that explain what the function does.

# %% [markdown]
# ## 🔹 **Why Use Functions?**

# %% [markdown]
# Imagine you need to convert temperatures from Fahrenheit to Celsius several times in your program. Without functions, you would have to write the same calculation code repeatedly:

# %% [markdown]
# #### Example

# %% [markdown]
# Without functions - repetitive code:

# %%
temp1 = 77
celsius1 = (temp1 - 32) * 5 / 9
print(celsius1)

temp2 = 95
celsius2 = (temp2 - 32) * 5 / 9
print(celsius2)

temp3 = 50
celsius3 = (temp3 - 32) * 5 / 9
print(celsius3)
# Out:
# 25.0
# 35.0
# 10.0

# %% [markdown]
# With functions, you write the code once and reuse it:

# %% [markdown]
# #### Example

# %% [markdown]
# With functions - reusable code:

# %%
def fahrenheit_to_celsius(fahrenheit):
  return (fahrenheit - 32) * 5 / 9

print(fahrenheit_to_celsius(77))
print(fahrenheit_to_celsius(95))
print(fahrenheit_to_celsius(50))
# Out:
# 25.0
# 35.0
# 10.0

# %% [markdown]
# ## 🔹 **Return Values**

# %% [markdown]
# Functions can send data back to the code that called them using the `return` statement.
#
# When a function reaches a `return` statement, it stops executing and sends the result back:

# %% [markdown]
# #### Example

# %% [markdown]
# A function that returns a value:

# %%
def get_greeting():
  return "Hello from a function"

message = get_greeting()
print(message)
# Out:
# Hello from a function

# %% [markdown]
# You can use the returned value directly:

# %% [markdown]
# #### Example

# %% [markdown]
# Using the return value directly:

# %%
def get_greeting():
  return "Hello from a function"

print(get_greeting())
# Out:
# Hello from a function

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# If a function doesn't have a <code>return</code> statement, it returns <code>None</code> by default.

# %% [markdown]
# ## 🔹 **The pass Statement**

# %% [markdown]
# Function definitions cannot be empty. If you need to create a function placeholder without any code, use the `pass` statement:

# %% [markdown]
# #### Example

# %%
def my_function():
  pass

# %% [markdown]
# The `pass` statement is often used when developing, allowing you to define the structure first and implement details later.

# %% [markdown]
# # **Python Function Arguments**
# ---

# %% [markdown]
# ## 🔹 **Arguments**

# %% [markdown]
# Information can be passed into functions as arguments.
#
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:

# %% [markdown]
# #### Example

# %% [markdown]
# A function with one argument:

# %%
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes

# %% [markdown]
# ## 🔹 **Parameters vs Arguments**

# %% [markdown]
# The terms *parameter* and *argument* can be used for the same thing: information that are passed into a function.

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>From a function's perspective:</b><br>
# A <b>parameter</b> is the variable listed inside the parentheses in the function definition.<br>
# An <b>argument</b> is the actual value that is sent to the function when it is called.

# %% [markdown]
# #### Example

# %%
def my_function(name): # name is a parameter
  print("Hello", name)

my_function("Emil") # "Emil" is an argument
# Out:
# Hello Emil

# %% [markdown]
# ## 🔹 **Number of Arguments**

# %% [markdown]
# By default, a function must be called with the correct number of arguments.
#
# If your function expects 2 arguments, you must call it with exactly 2 arguments.

# %% [markdown]
# #### Example

# %% [markdown]
# This function expects 2 arguments, and gets 2 arguments::

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil", "Refsnes")
# Out:
# Emil Refsnes

# %% [markdown]
# If you try to call the function with the wrong number of arguments, you will get an error:

# %% [markdown]
# #### Example

# %% [markdown]
# This function expects 2 arguments, but gets only 1:

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2663467011.py in <cell line: 0>()
#       2   print(fname + " " + lname)
#       3
# ----> 4 my_function("Emil")
#
# TypeError: my_function() missing 1 required positional argument: 'lname'

# %% [markdown]
# ## 🔹 **Default Parameter Values**

# %% [markdown]
# You can assign default values to parameters. If the function is called without an argument, it uses the default value:

# %% [markdown]
# #### Example

# %%
def my_function(name = "friend"):
  print("Hello", name)

my_function("Emil")
my_function("Tobias")
my_function()
my_function("Linus")
# Out:
# Hello Emil
# Hello Tobias
# Hello friend
# Hello Linus

# %% [markdown]
# #### Example

# %% [markdown]
# Default value for country parameter:

# %%
def my_function(country = "Norway"):
  print("I am from", country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %% [markdown]
# ## 🔹 **Keyword Arguments**

# %% [markdown]
# You can send arguments with the *key = value* syntax.

# %% [markdown]
# #### Example

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(animal = "dog", name = "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %% [markdown]
# This way, with keyword arguments, the order of the arguments does not matter.

# %% [markdown]
# #### Example

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(name = "Buddy", animal = "dog")
# Out:
# I have a dog
# My dog's name is Buddy

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# The phrase <i>Keyword Arguments</i> is often shortened to <i>kwargs</i> in Python documentation.

# %% [markdown]
# ## 🔹 **Positional Arguments**

# %% [markdown]
# When you call a function with arguments without using keywords, they are called positional arguments.
#
# Positional arguments must be in the correct order:

# %% [markdown]
# #### Example

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("dog", "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %% [markdown]
# The order matters with positional arguments:

# %% [markdown]
# #### Example

# %% [markdown]
# Switching the order changes the result:

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("Buddy", "dog")
# Out:
# I have a Buddy
# My Buddy's name is dog

# %% [markdown]
# ## 🔹 **Mixing Positional and Keyword Arguments**

# %% [markdown]
# You can mix positional and keyword arguments in a function call.
#
# However, positional arguments must come before keyword arguments:

# %% [markdown]
# #### Example

# %%
def my_function(animal, name, age):
  print("I have a", age, "year old", animal, "named", name)

my_function("dog", name = "Buddy", age = 5)
# Out:
# I have a 5 year old dog named Buddy

# %% [markdown]
# ## 🔹 **Passing Different Data Types**

# %% [markdown]
# You can send any data type as an argument to a function (string, number, list, dictionary, etc.).
#
# The data type will be preserved inside the function:

# %% [markdown]
# #### Example

# %% [markdown]
# Sending a list as an argument:

# %%
def my_function(fruits):
  for fruit in fruits:
    print(fruit)

my_fruits = ["apple", "banana", "cherry"]
my_function(my_fruits)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# #### Example

# %% [markdown]
# Sending a dictionary as an argument:

# %%
def my_function(person):
  print("Name:", person["name"])
  print("Age:", person["age"])

my_person = {"name": "Emil", "age": 25}
my_function(my_person)
# Out:
# Name: Emil
# Age: 25

# %% [markdown]
# ## 🔹 **Return Values**

# %% [markdown]
# Functions can return values using the `return` statement:

# %% [markdown]
# #### Example

# %%
def my_function(x, y):
  return x + y

result = my_function(5, 3)
print(result)
# Out:
# 8

# %% [markdown]
# ## 🔹 **Returning Different Data Types**

# %% [markdown]
# Functions can return any data type, including lists, tuples, dictionaries, and more.

# %% [markdown]
# #### Example

# %% [markdown]
# A function that returns a list:

# %%
def my_function():
  return ["apple", "banana", "cherry"]

fruits = my_function()
print(fruits[0])
print(fruits[1])
print(fruits[2])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# #### Example

# %% [markdown]
# A function that returns a tuple:

# %%
def my_function():
  return (10, 20)

x, y = my_function()
print("x:", x)
print("y:", y)
# Out:
# x: 10
# y: 20

# %% [markdown]
# ## 🔹 **Positional-Only Arguments**

# %% [markdown]
# You can specify that a function can have ONLY positional arguments.
#
# To specify positional-only arguments, add `,` `/` after the arguments:

# %% [markdown]
# #### Example

# %%
def my_function(name, /):
  print("Hello", name)

my_function("Emil")
# Out:
# Hello Emil

# %% [markdown]
# Without the `,` `/` you are actually allowed to use keyword arguments even if the function expects positional arguments:

# %% [markdown]
# #### Example

# %%
def my_function(name):
  print("Hello", name)

my_function(name = "Emil")
# Out:
# Hello Emil

# %% [markdown]
# With `,` `/`, you will get an error if you try to use keyword arguments:

# %% [markdown]
# #### Example

# %%
def my_function(name, /):
  print("Hello", name)

my_function(name = "Emil")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-895733256.py in <cell line: 0>()
#       2   print("Hello", name)
#       3
# ----> 4 my_function(name = "Emil")
#
# TypeError: my_function() got some positional-only arguments passed as keyword arguments: 'name'

# %% [markdown]
# ## 🔹 **Keyword-Only Arguments**

# %% [markdown]
# To specify that a function can have only keyword arguments, add `*,` before the arguments:

# %% [markdown]
# #### Example

# %%
def my_function(*, name):
  print("Hello", name)

my_function(name = "Emil")
# Out:
# Hello Emil

# %% [markdown]
# Without `*,`, you are allowed to use positional arguments even if the function expects keyword arguments:

# %% [markdown]
# #### Example

# %%
def my_function(name):
  print("Hello", name)

my_function("Emil")
# Out:
# Hello Emil

# %% [markdown]
# With `*,`, you will get an error if you try to use positional arguments:

# %% [markdown]
# #### Example

# %%
def my_function(*, name):
  print("Hello", name)

my_function("Emil")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2564680531.py in <cell line: 0>()
#       2   print("Hello", name)
#       3
# ----> 4 my_function("Emil")
#
# TypeError: my_function() takes 0 positional arguments but 1 was given

# %% [markdown]
# ## 🔹 **Combining Positional-Only and Keyword-Only**

# %% [markdown]
# You can combine both argument types in the same function.
#
# Arguments before `/` are positional-only, and arguments after `*` are keyword-only:

# %% [markdown]
# #### Example

# %%
def my_function(a, b, /, *, c, d):
  return a + b + c + d

result = my_function(5, 10, c = 15, d = 20)
print(result)
# Out:
# 50

# %% [markdown]
# # **Python \*args and  \*\*kwargs**
# ---

# %% [markdown]
# ## 🔹 **\*args and \*\*kwargs**

# %% [markdown]
# By default, a function must be called with the correct number of arguments.
#
# However, sometimes you may not know how many arguments that will be passed into your function.
#
# *args and **kwargs allow functions to accept a unknown number of arguments.

# %% [markdown]
# ## 🔹 **Arbitrary Arguments -\*args**

# %% [markdown]
# If you do not know how many arguments will be passed into your function, add a `*` before the parameter name.
#
# This way, the function will receive a tuple of arguments and can access the items accordingly:

# %% [markdown]
# #### Example

# %% [markdown]
# Using *args to accept any number of arguments:

# %%
def my_function(*kids):
  print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <i>Arbitrary Arguments</i> are often shortened to <i>*args</i> in Python documentation.

# %% [markdown]
# ## 🔹 **What is \*args?**

# %% [markdown]
# The `*args` parameter allows a function to accept any number of positional arguments.
#
# Inside the function, `args` becomes a tuple containing all the passed arguments:

# %% [markdown]
# #### Example

# %% [markdown]
# Accessing individual arguments from *args:

# %%
def my_function(*args):
  print("Type:", type(args))
  print("First argument:", args[0])
  print("Second argument:", args[1])
  print("All arguments:", args)

my_function("Emil", "Tobias", "Linus")
# Out:
# Type: <class 'tuple'>
# First argument: Emil
# Second argument: Tobias
# All arguments: ('Emil', 'Tobias', 'Linus')

# %% [markdown]
# ## 🔹 **Using \*args with Regular Arguments**

# %% [markdown]
# You can combine regular parameters with *args.
#
# Regular parameters must come before *args:

# %% [markdown]
# #### Example

# %%
def my_function(greeting, *names):
  for name in names:
    print(greeting, name)

my_function("Hello", "Emil", "Tobias", "Linus")
# Out:
# Hello Emil
# Hello Tobias
# Hello Linus

# %% [markdown]
# In this example, `"Hello"` is assigned to `greeting`, and the rest are collected in `names`.

# %% [markdown]
# ## 🔹 **Practical Example with \*args**

# %% [markdown]
# *args is useful when you want to create flexible functions:

# %% [markdown]
# #### Example

# %% [markdown]
# A function that calculates the sum of any number of values:

# %%
def my_function(*numbers):
  total = 0
  for num in numbers:
    total += num
  return total

print(my_function(1, 2, 3))
print(my_function(10, 20, 30, 40))
print(my_function(5))
# Out:
# 6
# 100
# 5

# %% [markdown]
# #### Example

# %% [markdown]
# Finding the maximum value:

# %%
def my_function(*numbers):
  if len(numbers) == 0:
    return None
  max_num = numbers[0]
  for num in numbers:
    if num > max_num:
      max_num = num
  return max_num

print(my_function(3, 7, 2, 9, 1))
# Out:
# 9

# %% [markdown]
# ## 🔹 **Arbitrary Keyword Arguments - \*\*kwargs**

# %% [markdown]
# If you do not know how many keyword arguments will be passed into your function, add two asterisks `**` before the parameter name.
#
# This way, the function will receive a dictionary of arguments and can access the items accordingly:

# %% [markdown]
# #### Example

# %% [markdown]
# Using **kwargs to accept any number of keyword arguments:

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# Arbitrary <i>Keyword Arguments</i> are often shortened to <i>**kwargs</i> in Python documentation.

# %% [markdown]
# ## 🔹 **What is \*\*kwargs?**

# %% [markdown]
# The `**kwargs` parameter allows a function to accept any number of keyword arguments.
#
# Inside the function, `kwargs` becomes a dictionary containing all the keyword arguments:

# %% [markdown]
# #### Example

# %% [markdown]
# Accessing values from **kwargs:

# %% [markdown]
# #### Example

# %%
def my_function(**myvar):
  print("Type:", type(myvar))
  print("Name:", myvar["name"])
  print("Age:", myvar["age"])
  print("All data:", myvar)

my_function(name = "Tobias", age = 30, city = "Bergen")
# Out:
# Type: <class 'dict'>
# Name: Tobias
# Age: 30
# All data: {'name': 'Tobias', 'age': 30, 'city': 'Bergen'}

# %% [markdown]
# ## 🔹 **Using \*\*kwargs with Regular Arguments**

# %% [markdown]
# You can combine regular parameters with `**kwargs`.
#
# Regular parameters must come before `**kwargs`:

# %% [markdown]
# #### Example

# %%
def my_function(username, **details):
  print("Username:", username)
  print("Additional details:")
  for key, value in details.items():
    print(" ", key + ":", value)

my_function("emil123", age = 25, city = "Oslo", hobby = "coding")
# Out:
# Username: emil123
# Additional details:
#   age: 25
#   city: Oslo
#   hobby: coding

# %% [markdown]
# ## 🔹 **Combining \*args and \*\*kwargs**

# %% [markdown]
# You can use both *args and **kwargs in the same function.
#
# The order must be:
#
# 1. regular parameters
# 2. *args
# 3. **kwargs

# %% [markdown]
# #### Example

# %%
def my_function(title, *args, **kwargs):
  print("Title:", title)
  print("Positional arguments:", args)
  print("Keyword arguments:", kwargs)

my_function("User Info", "Emil", "Tobias", age = 25, city = "Oslo")
# Out:
# Title: User Info
# Positional arguments: ('Emil', 'Tobias')
# Keyword arguments: {'age': 25, 'city': 'Oslo'}

# %% [markdown]
# ## 🔹 **Unpacking Arguments**

# %% [markdown]
# The `*` and `**` operators can also be used when calling functions to unpack (expand) a list or dictionary into separate arguments.

# %% [markdown]
# ### 🔸 *Unpacking Lists with \**

# %% [markdown]
# If you have values stored in a list, you can use `*` to unpack them into individual arguments:

# %% [markdown]
# #### Example

# %% [markdown]
# Using * to unpack a list into arguments:

# %%
def my_function(a, b, c):
  return a + b + c

numbers = [1, 2, 3]
result = my_function(*numbers) # Same as: my_function(1, 2, 3)
print(result)
# Out:
# 6

# %% [markdown]
# ### 🔸 *Unpacking Dictionaries with \*\**

# %% [markdown]
# If you have keyword arguments stored in a dictionary, you can use `**` to unpack them:

# %% [markdown]
# #### Example

# %% [markdown]
# Using ** to unpack a dictionary into keyword arguments:

# %%
def my_function(fname, lname):
  print("Hello", fname, lname)

person = {"fname": "Emil", "lname": "Refsnes"}
my_function(**person) # Same as: my_function(fname="Emil", lname="Refsnes")
# Out:
# Hello Emil Refsnes

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Remember:</b> Use <code>*</code> and <code>**</code> in function definitions to <i>collect</i> arguments, and use them in function calls to <i>unpack</i> arguments.

# %% [markdown]
# <a id = "10"></a>
# # ⚠️ **Challenge #10**
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Challenge: </b>  Build a function that calculates the average of the arguments given to it.

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFE98A; color: black;">
# <b>1. Enter grades</b>

# %%
# Function to enter grades
def enter_grades():
    grades = []
    n = int(input("How many grades do you want to enter?: "))

    for i in range(n):
        grade = float(input(f"Enter grade #{i+1}: "))
        grades.append(grade)

    return grades

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFE98A; color: black;">
# <b>2. Calculate average</b>

# %%
# Function to calculate average
def calculate_average(grades_list):
    if len(grades_list) == 0:
        return 0  # avoid division by 0
    return sum(grades_list) / len(grades_list)

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFE98A; color: black;">
# <b>3. Output</b>

# %%
# main program
grades = enter_grades()
average = calculate_average(grades)

print(f"\nThe average of the grades is: {average:.2f}")
# Out:
# How many grades do you want to enter?: 3
# Enter grade #1: 16.45
# Enter grade #2: 19.56
# Enter grade #3: 18.23
#
# The average of the grades is: 18.08

# %% [markdown]
# 19# **Python Scope**
# ---

# %% [markdown]
# ## 🔹 **Scope**

# %% [markdown]
# A variable is only available from inside the region it is created. This is called **scope**.

# %% [markdown]
# ## 🔹 **Local Scope**

# %% [markdown]
# A variable created inside a function belongs to the local scope of that function, and can only be used inside that function.

# %% [markdown]
# #### Example

# %% [markdown]
# A variable created inside a function is available inside that function:

# %%
def myfunc():
  x = 300
  print(x)

myfunc()
# Out:
# 300

# %% [markdown]
# ### 🔸 *Function Inside Function*

# %% [markdown]
# As explained in the example above, the variable `x` is not available outside the function, but it is available for any function inside the function:

# %% [markdown]
# #### Example

# %% [markdown]
# The local variable can be accessed from a function within the function:

# %%
def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()
# Out:
# 300

# %% [markdown]
# ## 🔹 **Global Scope**

# %% [markdown]
# A variable created in the main body of the Python code is a global variable and belongs to the global scope.
#
# Global variables are available from within any scope, global and local.

# %% [markdown]
# #### Example

# %% [markdown]
# A variable created outside of a function is global and can be used by anyone:

# %%
x = 300

def myfunc():
  print(x)

myfunc()

print(x)
# Out:
# 300
# 300

# %% [markdown]
# ### 🔸 *Naming Variables*

# %% [markdown]
# If you operate with the same variable name inside and outside of a function, Python will treat them as two separate variables, one available in the global scope (outside the function) and one available in the local scope (inside the function):

# %% [markdown]
# #### Example

# %% [markdown]
# The function will print the local `x`, and then the code will print the global x:

# %%
x = 300

def myfunc():
  x = 200
  print(x)

myfunc()

print(x)
# Out:
# 200
# 300

# %% [markdown]
# ## 🔹 **Global Keyword**

# %% [markdown]
# If you need to create a global variable, but are stuck in the local scope, you can use the `global` keyword.
#
# The `global` keyword makes the variable global.

# %% [markdown]
# #### Example

# %% [markdown]
# If you use the `global` keyword, the variable belongs to the global scope:

# %%
def myfunc():
  global x
  x = 300

myfunc()

print(x)
# Out:
# 300

# %% [markdown]
# Also, use the `global` keyword if you want to make a change to a global variable inside a function.

# %% [markdown]
# #### Example

# %% [markdown]
# To change the value of a global variable inside a function, refer to the variable by using the `global` keyword:

# %% [markdown]
# #### Example

# %%
x = 300

def myfunc():
  global x
  x = 200

myfunc()

print(x)
# Out:
# 200

# %% [markdown]
# ## 🔹 **Nonlocal Keyword**

# %% [markdown]
# The `nonlocal` keyword is used to work with variables inside nested functions.
#
# The `nonlocal` keyword makes the variable belong to the outer function.

# %% [markdown]
# #### Example

# %% [markdown]
# If you use the `nonlocal` keyword, the variable will belong to the outer function:

# %%
def myfunc1():
  x = "Jane"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())
# Out:
# hello

# %% [markdown]
# ## 🔹 **The LEGB Rule**

# %% [markdown]
# Python follows the **LEGB** rule when looking up variable names, and searches for them in this order:
#
# 1. **L**ocal - Inside the current function
# 2. **E**nclosing - Inside enclosing functions (from inner to outer)
# 3. **G**lobal - At the top level of the module
# 4. **B**uilt-in - In Python's built-in namespace

# %% [markdown]
# #### Example

# %% [markdown]
# Understanding the LEGB rule:

# %%
x = "global"

def outer():
  x = "enclosing"
  def inner():
    x = "local"
    print("Inner:", x)
  inner()
  print("Outer:", x)

outer()
print("Global:", x)
# Out:
# Inner: local
# Outer: enclosing
# Global: global

# %% [markdown]
# # **Python Decorators**
# ---

# %% [markdown]
# Decorators let you add extra behavior to a function, without changing the function's code.
#
# A decorator is a function that takes another function as input and returns a new function.

# %% [markdown]
# ## 🔹 **Basic Decorator**

# %% [markdown]
# Define the decorator first, then apply it with `@decorator_name` above the function.

# %% [markdown]
# #### Example

# %% [markdown]
# A basic decorator that uppercases the return value of the decorated function.

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Hello Sally"

print(myfunction())
# Out:
# HELLO SALLY

# %% [markdown]
# By placing `@changecase` directly above the function definition, the function myfunction is being "decorated" with the `changecase `function.
#
# The function `changecase` is the decorator.
#
# The function `myfunction` is the function that gets decorated.

# %% [markdown]
# ## 🔹 **Multiple Decorator Calls**

# %% [markdown]
# A decorator can be called multiple times. Just place the decorator above the function you want to decorate.

# %% [markdown]
# #### Example

# %% [markdown]
# Using the `@changecase` decorator on two functions:

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Hello Sally"

@changecase
def otherfunction():
  return "I am speed!"

print(myfunction())
print(otherfunction())
# Out:
# HELLO SALLY
# I AM SPEED!

# %% [markdown]
# ## 🔹 **Arguments in the Decorated Function**

# %% [markdown]
# Functions that requires arguments can also be decorated, just make sure you pass the arguments to the wrapper function:

# %% [markdown]
# #### Example

# %% [markdown]
# Functions with arguments can also be decorated:

# %%
def changecase(func):
  def myinner(x):
    return func(x).upper()
  return myinner

@changecase
def myfunction(nam):
  return "Hello " + nam

print(myfunction("John"))
# Out:
# HELLO JOHN

# %% [markdown]
# ## 🔹 **\*args and \*\*kwargs**

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# Sometimes the decorator function has no control over the arguments passed from decorated function, to solve this problem, add (<code>*args</code>, <code>**kwargs</code>) to the wrapper function, this way the wrapper function can accept any number, and any type of arguments, and pass them to the decorated function.

# %% [markdown]
# #### Example

# %% [markdown]
# Secure the function with `*args` and `**kwargs` arguments:

# %%
def changecase(func):
  def myinner(*args, **kwargs):
    return func(*args, **kwargs).upper()
  return myinner

@changecase
def myfunction(nam):
  return "Hello " + nam

print(myfunction("John"))
# Out:
# HELLO JOHN

# %% [markdown]
# ## 🔹 **Decorator With Arguments**

# %% [markdown]
# Decorators can accept their own arguments by adding another wrapper level.

# %% [markdown]
# #### Example

# %% [markdown]
# A decorator factory that takes an argument and transforms the casing based on the argument value.

# %%
def changecase(n):
  def changecase(func):
    def myinner():
      if n == 1:
        a = func().lower()
      else:
        a = func().upper()
      return a
    return myinner
  return changecase

@changecase(1)
def myfunction():
  return "Hello Linus"

print(myfunction())
# Out:
# hello linus

# %% [markdown]
# ## 🔹 **Multiple Decorators**

# %% [markdown]
# You can use multiple decorators on one function.
#
# This is done by placing the decorator calls on top of each other.
#
# Decorators are called in the reverse order, starting with the one closest to the function.

# %% [markdown]
# #### Example

# %% [markdown]
# One decorator for upper case, and one for adding a greeting:

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

def addgreeting(func):
  def myinner():
    return "Hello " + func() + " Have a good day!"
  return myinner

@changecase
@addgreeting
def myfunction():
  return "Tobias"

print(myfunction())
# Out:
# HELLO TOBIAS HAVE A GOOD DAY!

# %% [markdown]
# ## 🔹 **Preserving Function Metadata**

# %% [markdown]
# Functions in Python has metadata that can be accessed using the `__name__` and `__doc__` attributes.

# %% [markdown]
# #### Example

# %% [markdown]
# Normally, a function's name can be returned with the `__name__` attribute:

# %%
def myfunction():
  return "Have a great day!"

print(myfunction.__name__)
# Out:
# myfunction

# %% [markdown]
# But, when a function is decorated, the metadata of the original function is lost.

# %% [markdown]
# #### Example

# %% [markdown]
# Try returning the name from a decorated function and you will not get the same result:

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Have a great day!"

print(myfunction.__name__)
# Out:
# myinner

# %% [markdown]
# To fix this, Python has a built-in function called `functools.wraps` that can be used to preserve the original function's name and docstring.

# %% [markdown]
# #### Example

# %% [markdown]
# Import `functools.wraps` to preserve the original function name and docstring.

# %% [markdown]
# #### Example

# %%
import functools

def changecase(func):
  @functools.wraps(func)
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Have a great day!"

print(myfunction.__name__)
# Out:
# myfunction

# %% [markdown]
# # **Python Lambda**
# ---

# %% [markdown]
# ## 🔹 **Lambda Functions**

# %% [markdown]
# A lambda function is a small anonymous function.
#
# A lambda function can take any number of arguments, but can only have one expression.

# %% [markdown]
# ## 🔹 **Syntax**

# %%
lambda arguments : expression

# %% [markdown]
# The expression is executed and the result is returned:

# %% [markdown]
# #### Example

# %% [markdown]
# Add 10 to argument `a`, and return the result:

# %%
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %% [markdown]
# Lambda functions can take any number of arguments:

# %% [markdown]
# #### Example

# %% [markdown]
# Multiply argument `a` with argument `b` and return the result:

# %%
x = lambda a, b : a * b
print(x(5, 6))
# Out:
# 30

# %% [markdown]
# #### Example

# %% [markdown]
# Summarize argument `a`, `b`, and `c` and return the result:

# %%
x = lambda a, b, c : a + b + c
print(x(5, 6, 2))
# Out:
# 13

# %% [markdown]
# ## 🔹 **Why Use Lambda Functions?**

# %% [markdown]
# The power of lambda is better shown when you use them as an anonymous function inside another function.
#
# Say you have a function definition that takes one argument, and that argument will be multiplied with an unknown number:

# %%
def myfunc(n):
  return lambda a : a * n

# %% [markdown]
# Use that function definition to make a function that always doubles the number you send in:

# %% [markdown]
# #### Example

# %%
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)

print(mydoubler(11))
# Out:
# 22

# %% [markdown]
# Or, use the same function definition to make a function that always *triples* the number you send in:

# %% [markdown]
# #### Example

# %%
def myfunc(n):
  return lambda a : a * n

mytripler = myfunc(3)

print(mytripler(11))
# Out:
# 33

# %% [markdown]
# Or, use the same function definition to make both functions, in the same program:

# %% [markdown]
# #### Example

# %%
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)
mytripler = myfunc(3)

print(mytripler(11))
# Out:
# 33

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# Use lambda functions when an anonymous function is required for a short period of time.

# %% [markdown]
# Lambda functions are commonly used with built-in functions like `map()`, `filter()`, and `sorted()`.
