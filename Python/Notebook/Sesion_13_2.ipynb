# %% [markdown]
# <table style="width: 100%; background-color: transparent;">
#     <tr>
#         <!-- Columna del texto alineado al centro -->
#         <td width="75%" style="text-align: center; vertical-align: middle; padding-left: 50px;">
#             <!-- Contenedor del bloque de texto centrado -->
#             <div style="display: inline-block;">
#                 <span style="display: block; font-size: 70px; font-weight: bold; color: #f25625;">
#                     Introduction to Python
#                 </span>
#                 <span style="display: block; font-size: 50px; font-weight: bold; color: #f25625;">
#                     Lecture Notes
#                 </span>
#                 <span style="display: block; font-size: 30px; font-weight: bold; color: #f25625;">
#                     September 2025
#                 </span>
#             </div>
#         </td>
#         <!-- Columna de la imagen alineada a la derecha -->
#         <td width="25%" style="text-align: right; vertical-align: middle; padding-right: 50px;">
#             <img
#                 src="data:image/png;base64,..."
#                 width="300"
#                 style="display: block; margin-left: auto;"
#             />
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <p style="text-align:right; font-style: italic; font-size: 20px;">
#   <span style="font-weight: bold;">Autor:</span> Michael Steven Paucar Rojas
# </p>

# %% [markdown]
# <table style="width: 100%; font-size: 20px;font-weight: bold;">
#   <tr>
#     <td style="text-align: left;">
#       Session - 13
#     </td>
#     <td style="text-align: right;">
#       📅 2025/11/20
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## Contents
# 1. [Matplotlib  Introduction](#1)
#     1. [What is Matplotlib?](#1.1)
#     2. [Where is the Matplotlib Codebase?](#1.2)
# 2. [Matplotlib Getting Started](#2)
#     1. [Installation of Matplotlib](#2.1)
#     2. [Import Matplotlib](#2.2)
#     3. [Checking Matplotlib Version](#2.3)
# 3. [%matplotlib inline vs. Exporting as PNG in Matplotlib](#2)
#     1. [%matplotlib inline](#2.1)
#     2. [Exporting as PNG (or any other format) using plt.savefig()](#2.2)
# 4. [Matplotlib Pyplot](#3)
#      1. [Pyplot](#3.1)
# 5. [Matplotlib Plotting](#4)
#     1. [Plotting x and y points](#4.1)
#     2. [Plotting Without Line](#4.2)
#     3. [Multiple Points](#4.3)
#     4. [Default X-Points](#4.4)
# 6. [Matplotlib Markers](#5)
#     1. [Markers](#5.1)
#     2. [Marker Reference](#5.2)
#     3. [Format Strings `fmt`](#5.3)
#     4. [Line Reference](#5.4)
#     5. [Color Reference](#5.5)
#     6. [Marker Size](#5.6)
#     7. [Marker Color](#5.7)
# 7. [Matplotlib Line](#6)
#     1. [Linestyle](#6.1)
#     2. [Shorter Syntax](#6.2)
#     3. [Line Styles](#6.3)
#     4. [Line Color](#6.4)
#     5. [Line Width](#6.5)
#     6. [Multiple Lines](#6.6)
# 8. [Matplotlib Labels and Title](#7)
#     1. [Create Labels for a Plot](#7.1)
#     2. [Create a Title for a Plot](#7.2)
#     3. [Set Font Properties for Title and Labels](#7.3)
#     4. [Position the Title](#7.4)
# 9. [Matplotlib Adding Grid Lines](#8)
#     1. [Add Grid Lines to a Plot](#8.1)
#     2. [Specify Which Grid Lines to Display](#8.2)
#     3. [Set Line Properties for the Grid](#8.3)
# 10. [Matplotlib Subplot](#9)
#     1. [Display Multiple Plots](#9.1)
#     2. [The subplot() Function](#9.2)
#     3. [Title](#9.3)
#     4. [Super Title](#9.4)
# 11. [Matplotlib Scatter](#9.6)
#     1. [Creating Scatter Plots](#9.1)
#     2. [Compare Plots](#9.2)
#     3. [Colors](#9.3)
#     4. [Color Each Dot](#9.4)
#     5. [ColorMap](#9.5)
#     6. [Available ColorMaps](#9.6)
#     7. [Size](#9.7)
#     8. [Alpha](#9.8)
#     9. [Combine Color Size and Alpha](#9.9)
# 12. [Matplotlib Bars](#11)
#     1. [Creating Bars](#11.1)
#     2. [Horizontal Bars](#11.2)
#     3. [Bar Color](#11.3)
#     4. [Bar Width](#11.4)
#     5. [Bar Height](#11.5)
# 13. [Matplotlib Histograms](#12)
#     1. [Histogram](#12.1)
#     2. [Create Histogram](#12.2)
# 14. [Matplotlib Pie Charts](#13)
#     1. [Creating Pie Charts](#13.1)
#     2. [Labels](#13.2)
#     3. [Start Angle](#13.3)
#     4. [Explode](#13.4)
#     5. [Shadow](#13.5)
#     6. [Colors](#13.6)
#     7. [Legend](#13.7)

# %% [markdown]
# # <center> **Python Modules**

# %% [markdown]
# # **Matplotlib Introduction**
# ---

# %% [markdown]
# ## 🔹 **What is Matplotlib?**

# %% [markdown]
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %% [markdown]
# ## 🔹 **Where is the Matplotlib Codebase?**

# %% [markdown]
# The source code for Matplotlib is located at this github repository [https://github.com/matplotlib/matplotlib](https://github.com/matplotlib/matplotlib)

# %% [markdown]
# # **Matplotlib Getting Started**
# ---

# %% [markdown]
# ## 🔹 **Installation of Matplotlib**

# %% [markdown]
# If you have Python and PIP already installed on a system, then installation of Matplotlib is very easy.
#
# Install it using this command:

# %% [markdown]
# >C:\Users\Your Name>pip install matplotlib

# %% [markdown]
# If this command fails, then use a python distribution that already has Matplotlib installed,  like Anaconda, Spyder etc.

# %% [markdown]
# ## 🔹 **Import Matplotlib**

# %% [markdown]
# Once Matplotlib is installed, import it in your applications by adding the `import module` statement:

# %%
import matplotlib

# %% [markdown]
# Now Matplotlib is imported and ready to use:

# %% [markdown]
# ## 🔹 **Checking Matplotlib Version**

# %% [markdown]
# The version string is stored under `__version__` attribute.

# %% [markdown]
# #### Example

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.8.4

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b> two underscore characters are used in __version__.

# %% [markdown]
# # **`%matplotlib inline` vs. Exporting as PNG in Matplotlib**
#
#
# ---

# %% [markdown]
# ## 🔹 **%matplotlib inline**

# %% [markdown]
# * **What does it do?:** This magic command is used in interactive notebooks like Jupyter or Google Colab to ensure that the plots generated by matplotlib are displayed directly inside the notebook below the code cell that generates them.
# * **Interactivity:** The plots may be interactive in some environments, allowing for data exploration in real-time.
# * **Main use:** It's ideal when you're exploring data interactively and only want to view the plots without saving them as files.
# * **Do you need to save?:** You don't need to save the plots as files, though you can do so if you want, using `plt.savefig()`.

# %% [markdown]
# ### Example

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
# The plot will automatically display below this cell without needing plt.show()

# %% [markdown]
# ## 🔹 **Exporting as PNG (or any other format) using `plt.savefig()`**

# %% [markdown]
# * **What does it do?:** Instead of displaying the plot immediately in the notebook, this option saves the plot to a file (e.g., PNG, PDF, etc.). This is useful when you need to ***save the plot for later use*** or when you cannot display the plot interactively in your environment.
# * **Interactivity:** The saved plot is static, meaning you cannot interact with it (such as zooming or panning).
# * **Main use:** It's ideal when you need to ***save plots for reports, presentations, or sharing with others***. It's also useful in *environments without a graphical user interface (GUI)*, such as servers or headless systems.
# * **Do you need to display?:** While you can display the saved image in the notebook (using IPython.display.Image), typically, the plot is just saved to a file.

# %% [markdown]
# #### Example

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)

# Save the plot as a PNG file
plt.savefig('sine_wave.png')

# Close the chart to free up resources and prevent images from accumulating
plt.close()

# Display the saved image in the notebook
from IPython.display import Image
Image(filename='sine_wave.png')

# %% [markdown]
# # **Matplotlib Pyplot**
# ---

# %% [markdown]
# ## 🔹 **Pyplot**

# %% [markdown]
# Most of the Matplotlib utilities lies under the `pyplot` submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# #### Example

# %% [markdown]
# Draw a line in a diagram from position (0,0) to position (6,250):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # **Matplotlib Plotting**
# ---

# %% [markdown]
# ## 🔹 **Plotting x and y points**

# %% [markdown]
# The `plot()` function is used to draw points (markers) in a diagram.
#
# By default, the `plot()` function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the **x-axis**.
#
# Parameter 2 is an array containing the points on the **y-axis**.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %% [markdown]
# #### Example

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to position (8, 10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# The <b>x-axis</b> is the horizontal axis.<br>
# The <b>y-axis</b> is the vertical axis.

# %% [markdown]
# ## 🔹 **Plotting Without Line**

# %% [markdown]
# To plot only the markers, you can use *shortcut string notation parameter* `'o'`, which means 'rings'.

# %% [markdown]
# #### Example

# %% [markdown]
# Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# ## 🔹 **Multiple Points**

# %% [markdown]
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %% [markdown]
# #### Example

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## 🔹 **Default X-Points**

# %% [markdown]
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %% [markdown]
# #### Example

# %% [markdown]
# Plotting without x-points:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# The x-points in the example above are [0, 1, 2, 3, 4, 5].

# %% [markdown]
# # **Matplotlib Markers**
# ---

# %% [markdown]
# ## 🔹 **Markers**

# %% [markdown]
# You can use the keyword argument `marker` to emphasize each point with a specified marker:

# %% [markdown]
# #### Example

# %% [markdown]
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# #### Example

# %% [markdown]
# Mark each point with a star:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# ## 🔹 **Marker Reference**

# %% [markdown]
# | Marker | Description         |
# |--------|---------------------|
# | 'o'    | Circle              |
# | '*'    | Star                |
# | '.'    | Point               |
# | ','    | Pixel               |
# | 'x'    | X                   |
# | 'X'    | X (filled)          |
# | '+'    | Plus                |
# | 'P'    | Plus (filled)       |
# | 's'    | Square              |
# | 'D'    | Diamond             |
# | 'd'    | Diamond (thin)      |
# | 'p'    | Pentagon            |
# | 'H'    | Hexagon             |
# | 'h'    | Hexagon             |
# | 'v'    | Triangle Down       |
# | '^'    | Triangle Up         |
# | '<'    | Triangle Left       |
# | '>'    | Triangle Right      |
# | '1'    | Tri Down            |
# | '2'    | Tri Up              |
# | '3'    | Tri Left            |
# | '4'    | Tri Right           |
# | '\|'   | Vline               |
# | '_'    | Hline               |

# %% [markdown]
# ## 🔹 **Format Strings `fmt`**

# %% [markdown]
# You can also use the *shortcut string notation* parameter to specify the marker.
#
# This parameter is also called `fmt`, and is written with this syntax:
#
# `marker|line|color`

# %% [markdown]
# #### Example

# %% [markdown]
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# The marker value can be anything from the Marker Reference above.
#
# The line value can be one of the following:

# %% [markdown]
# ## 🔹 **Line Reference**

# %% [markdown]
# | Line Syntax | Description         |
# |-------------|---------------------|
# | '-'         | Solid line          |
# | ':'         | Dotted line         |
# | '--'        | Dashed line         |
# | '-.'        | Dashed/dotted line  |

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b> If you leave out the <i>line</i> value in the fmt parameter, no line will be plotted.

# %% [markdown]
# The short color value can be one of the following:

# %% [markdown]
# ## 🔹 **Color Reference**

# %% [markdown]
# | Color Syntax | Description |
# |--------------|-------------|
# | 'r'          | Red         |
# | 'g'          | Green       |
# | 'b'          | Blue        |
# | 'c'          | Cyan        |
# | 'm'          | Magenta     |
# | 'y'          | Yellow      |
# | 'k'          | Black       |
# | 'w'          | White       |

# %% [markdown]
# ## 🔹 **Marker Size**

# %% [markdown]
# You can use the keyword argument `markersize` or the shorter version, `ms` to set the size of the markers:

# %% [markdown]
# #### Example

# %% [markdown]
# Set the size of the markers to 20:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# ## 🔹 **Marker Color**

# %% [markdown]
# You can use the keyword argument `markeredgecolor` or the shorter `mec` to set the color of the edge of the markers:

# %% [markdown]
# #### Example

# %% [markdown]
# Set the EDGE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# You can use the keyword argument `markerfacecolor` or the shorter `mfc` to set the color inside the edge of the markers:

# %% [markdown]
# #### Example

# %% [markdown]
# Set the FACE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# Use *both* the `mec` and `mfc` arguments to color the entire marker:

# %% [markdown]
# #### Example

# %% [markdown]
# Set the color of both the *edge* and the *face* to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# You can also use [Hexadecimal color values](https://htmlcolorcodes.com/):

# %% [markdown]
# #### Example

# %% [markdown]
# Mark each point with a beautiful green color:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# Or any of the [140 supported color names](https://htmlcolorcodes.com/color-names/).

# %% [markdown]
# #### Example

# %% [markdown]
# Mark each point with the color named "hotpink":

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# # **Matplotlib Line**
# ---

# %% [markdown]
# ## 🔹 **Linestyle**

# %% [markdown]
# You can use the keyword argument `linestyle`, or shorter `ls`, to change the style of the plotted line:

# %% [markdown]
# #### Example

# %% [markdown]
# Use a dotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# #### Example

# %% [markdown]
# Use a dashed line:

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# ## 🔹 **Shorter Syntax**

# %% [markdown]
# The line style can be written in a shorter syntax:
#
# * **linestyle** can be written as `ls`.
# * **dotted** can be written as `:`.
# * **dashed** can be written as `--`.

# %% [markdown]
# #### Example

# %% [markdown]
# Shorter syntax:

# %%
plt.plot(ypoints, ls = ':')

# %% [markdown]
# ## 🔹 **Line Styles**

# %% [markdown]
# You can choose any of these styles:
#
# | Style         | Or      |
# |---------------|---------|
# | 'solid' (default) | '-'   |
# | 'dotted'     | ':'     |
# | 'dashed'     | '--'    |
# | 'dashdot'    | '-.'    |
# | 'None'       | '' or ' ' |

# %% [markdown]
# ## 🔹 **Line Color**

# %% [markdown]
# You can use the keyword argument `color` or the shorter `c` to set the color of the line:

# %% [markdown]
# #### Example

# %% [markdown]
# Set the line color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# You can also use [Hexadecimal color values](https://htmlcolorcodes.com/):

# %% [markdown]
# Plot with a beautiful yellow line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, c = '#FFEE00')
plt.show()

# %% [markdown]
# Or any of the [140 supported color names](https://htmlcolorcodes.com/color-names/).

# %% [markdown]
# Plot with the color named "DarkSalmon":

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, c = 'DarkSalmon')
plt.show()

# %% [markdown]
# ## 🔹 **Line Width**

# %% [markdown]
# You can use the keyword argument `linewidth` or the shorter `lw` to change the width of the line.
#
# The value is a floating number, in points:

# %% [markdown]
# #### Example

# %% [markdown]
# Plot with a 20.5pt wide line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# ## 🔹 **Multiple Lines**

# %% [markdown]
# You can plot as many lines as you like by simply adding more `plt.plot()` functions:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw two lines by specifying a `plt.plot()` function for each line:

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# You can also plot many lines by adding the points for the x- and y-axis for each line in the same `plt.plot()` function.
#
# (In the examples above we only specified the points on the y-axis, meaning that the points on the x-axis got the the default values (0, 1, 2, 3).)
#
# The x- and y- values come in pairs:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw two lines by specifiyng the x- and y-point values for both lines:

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # **Matplotlib Labels and Title**
# ---

# %% [markdown]
# ## 🔹 **Create Labels for a Plot**

# %% [markdown]
# With Pyplot, you can use the `xlabel()` and `ylabel()` functions to set a label for the x- and y-axis.

# %% [markdown]
# #### Example

# %% [markdown]
# Add labels to the x- and y-axis:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## 🔹 **Create a Title for a Plot**

# %% [markdown]
# With Pyplot, you can use the `title()` function to set a title for the plot.

# %% [markdown]
# #### Example

# %% [markdown]
# Add a plot title and labels for the x- and y-axis:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## 🔹 **Set Font Properties for Title and Labels**

# %% [markdown]
# You can use the `fontdict` parameter in `xlabel()`, `ylabel()`, and `title()` to set font properties for the title and labels.

# %% [markdown]
# #### Example

# %% [markdown]
# Set font properties for the title and labels:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 🔹 **Position the Title**

# %% [markdown]
# You can use the `loc` parameter in `title()` to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %% [markdown]
# #### Example

# %% [markdown]
# Position the title to the left:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # **Matplotlib Adding Grid Lines**
# ---

# %% [markdown]
# ## 🔹 **Add Grid Lines to a Plot**

# %% [markdown]
# With Pyplot, you can use the `grid()` function to add grid lines to the plot.

# %% [markdown]
# #### Example

# %% [markdown]
# Add grid lines to the plot:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## 🔹 **Specify Which Grid Lines to Display**

# %% [markdown]
# You can use the `axis` parameter in the `grid()` function to specify which grid lines to display.
#
# Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %% [markdown]
# #### Example

# %% [markdown]
# Display only grid lines for the x-axis:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# #### Example

# %% [markdown]
# Display only grid lines for the y-axis:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# ## 🔹 **Set Line Properties for the Grid**

# %% [markdown]
# You can also set the line properties of the grid, like this: grid(color = '*color*', linestyle = '*linestyle*', linewidth = *number*).

# %% [markdown]
# #### Example

# %% [markdown]
# Set the line properties of the grid:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# # **Matplotlib Subplot**
# ---

# %% [markdown]
# ## 🔹 **Display Multiple Plots**

# %% [markdown]
# With the `subplot()` function you can draw multiple plots in one figure:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 2 plots:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## 🔹 **The subplot() Function**

# %% [markdown]
# The `subplot()` function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.

# %% [markdown]
# ```
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
# ```

# %% [markdown]
# ```
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.
# ```

# %% [markdown]
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 2 plots on top of each other:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# You can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 6 plots:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## 🔹 **Title**

# %% [markdown]
# You can add a title to each plot with the `title()` function:

# %% [markdown]
# #### Example

# %% [markdown]
# 2 plots, with titles:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# ## 🔹 **Super Title**

# %% [markdown]
# You can add a title to the entire figure with the `suptitle()` function:

# %% [markdown]
# #### Example

# %% [markdown]
# Add a title for the entire figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # **Matplotlib Scatter**
# ---

# %% [markdown]
# ## 🔹 **Creating Scatter Plots**

# %% [markdown]
# With Pyplot, you can use the `scatter()` function to draw a scatter plot.
#
# The `scatter()` function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %% [markdown]
# #### Example

# %% [markdown]
# A simple scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# The observation in the example above is the result of 13 cars passing by.
#
# The X-axis shows how old the car is.
#
# The Y-axis shows the speed of the car when it passes.
#
# Are there any relationships between the observations?
#
# It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 13 cars.

# %% [markdown]
# ## 🔹 **Compare Plots**

# %% [markdown]
# In the example above, there seems to be a relationship between speed and age, but what if we plot the observations from another day as well? Will the scatter plot tell us something else?

# %% [markdown]
# #### Example

# %% [markdown]
# Draw two plots on the same figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b>  The two plots are plotted with two different colors, by default blue and orange, you will learn how to change colors later in this chapter.

# %% [markdown]
# By comparing the two plots, I think it is safe to say that they both gives us the same conclusion: the newer the car, the faster it drives.

# %% [markdown]
# ## 🔹 **Colors**

# %% [markdown]
# You can set your own color for each scatter plot with the `color` or the `c` argument:

# %% [markdown]
# #### Example

# %% [markdown]
# Set your own color of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ## 🔹 **Color Each Dot**

# %% [markdown]
# You can even set a specific color for each dot by using an array of colors as value for the `c` argument:

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b>  You <i>cannot</i> use the <code>color</code> argument for this, only the <code>c</code> argument.

# %% [markdown]
# #### Example

# %% [markdown]
# Set your own color of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ## 🔹 **ColorMap**

# %% [markdown]
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# Here is an example of a colormap:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of values from 0 to 100
values = np.linspace(0, 100, 256).reshape(1, -1)  # 1x256 array

# Display the values with the 'viridis' colormap
plt.imshow(values, aspect='auto', cmap='viridis', extent=[0, 100, 0, 1])
plt.colorbar()  # Adds the color bar to show the scale
plt.title("Viridis Colormap: 0 (purple) to 100 (yellow)")
plt.show()

# %% [markdown]
# This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color.

# %% [markdown]
# ### 🔸  *How to Use the ColorMap*

# %% [markdown]
# You can specify the colormap with the keyword argument `cmap` with the value of the colormap, in this case `'viridis'` which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %% [markdown]
# #### Example

# %% [markdown]
# Create a color array, and specify a colormap in the scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# You can include the colormap in the drawing by including the `plt.colorbar()` statement:

# %% [markdown]
# #### Example

# %% [markdown]
# Include the actual colormap:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ## 🔹 **Available ColorMaps**

# %% [markdown]
# You can choose any of the built-in colormaps:

# %% [markdown]
# | Name             | Reverse      |
# |------------------|--------------|
# | Accent           | Accent_r     |
# | Blues            | Blues_r      |
# | BrBG             | BrBG_r       |
# | BuGn             | BuGn_r       |
# | BuPu             | BuPu_r       |
# | CMRmap           | CMRmap_r     |
# | Dark2            | Dark2_r      |
# | GnBu             | GnBu_r       |
# | Greens           | Greens_r     |
# | Greys            | Greys_r      |
# | OrRd             | OrRd_r       |
# | Oranges          | Oranges_r    |
# | PRGn             | PRGn_r       |
# | Paired           | Paired_r     |
# | Pastel1          | Pastel1_r    |
# | Pastel2          | Pastel2_r    |
# | PiYG             | PiYG_r       |
# | PuBu             | PuBu_r       |
# | PuBuGn           | PuBuGn_r     |
# | PuOr             | PuOr_r       |
# | PuRd             | PuRd_r       |
# | Purples          | Purples_r    |
# | RdBu             | RdBu_r       |
# | RdGy             | RdGy_r       |
# | RdPu             | RdPu_r       |
# | RdYlBu           | RdYlBu_r     |
# | RdYlGn           | RdYlGn_r     |
# | Reds             | Reds_r       |
# | Set1             | Set1_r       |
# | Set2             | Set2_r       |
# | Set3             | Set3_r       |
# | Spectral         | Spectral_r   |
# | Wistia           | Wistia_r     |
# | YlGn             | YlGn_r       |
# | YlGnBu           | YlGnBu_r     |
# | YlOrBr           | YlOrBr_r     |
# | YlOrRd           | YlOrRd_r     |
# | afmhot           | afmhot_r     |
# | autumn           | autumn_r     |
# | binary           | binary_r     |
# | bone             | bone_r       |
# | brg              | brg_r        |
# | bwr              | bwr_r        |
# | cividis          | cividis_r    |
# | cool             | cool_r       |
# | coolwarm         | coolwarm_r   |
# | copper           | copper_r     |
# | cubehelix        | cubehelix_r  |
# | flag             | flag_r       |
# | gist_earth       | gist_earth_r |
# | gist_gray        | gist_gray_r  |
# | gist_heat        | gist_heat_r  |
# | gist_ncar        | gist_ncar_r  |
# | gist_rainbow     | gist_rainbow_r |
# | gist_stern       | gist_stern_r |
# | gist_yarg        | gist_yarg_r  |
# | gnuplot          | gnuplot_r    |
# | gnuplot2         | gnuplot2_r   |
# | gray             | gray_r       |
# | hot              | hot_r        |
# | hsv              | hsv_r        |
# | inferno          | inferno_r    |
# | jet              | jet_r        |
# | magma            | magma_r      |
# | nipy_spectral    | nipy_spectral_r |
# | ocean            | ocean_r      |
# | pink             | pink_r       |
# | plasma           | plasma_r     |
# | prism            | prism_r      |
# | rainbow          | rainbow_r    |
# | seismic          | seismic_r    |
# | spring           | spring_r     |
# | summer           | summer_r     |
# | tab10            | tab10_r      |
# | tab20            | tab20_r      |
# | tab20b           | tab20b_r     |
# | tab20c           | tab20c_r     |
# | terrain          | terrain_r    |
# | twilight         | twilight_r   |
# | twilight_shifted | twilight_shifted_r |
# | viridis          | viridis_r    |
# | winter           | winter_r     |

# %% [markdown]
# #### Example `spring`

# %%
import matplotlib
matplotlib.use('Agg')  # Use 'Agg' backend to avoid relying on the graphical interface

import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.randint(100, size=(100))  # Random x coordinates
y = np.random.randint(100, size=(100))  # Random y coordinates
colors = np.random.randint(100, size=(100))  # Random colors for the scatter plot

# Create the scatter plot with the 'spring' colormap
plt.scatter(x, y, c=colors, cmap='spring')

# Add a color bar to show the mapping of values to colors
plt.colorbar()

# Save the figure as a PNG file
plt.savefig('scatter_plot.png')  # Save the plot as a PNG image

# Close the figure to free up resources
plt.close()

# Display the saved image within Colab
from IPython.display import Image
Image(filename='scatter_plot.png')  # Display the saved PNG image within the notebook

# %% [markdown]
# #### Example `spring_r`

# %%
# Use this magic command to display plots inline in Jupyter/Colab
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.randint(100, size=(100))  # Random x coordinates
y = np.random.randint(100, size=(100))  # Random y coordinates
colors = np.random.randint(100, size=(100))  # Random colors for the scatter plot

# Create the scatter plot with the 'spring_r' colormap
plt.scatter(x, y, c=colors, cmap='spring_r')

# Add a color bar to show the mapping of values to colors
plt.colorbar()

# %% [markdown]
# ## 🔹 **Size**

# %% [markdown]
# You can change the size of the dots with the s argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %% [markdown]
# #### Example

# %% [markdown]
# Set your own size for the markers:

# %%
# Make matplotlib show plots inline in Jupyter/Colab
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# Define the data
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

# Create the scatter plot
plt.scatter(x, y, s=sizes, color='blue', alpha=0.5)

# Add labels and title
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter Plot with Varying Marker Sizes')

# Show the plot
plt.show()

# %% [markdown]
# ## 🔹 **Alpha**

# %% [markdown]
# You can adjust the transparency of the dots with the `alpha` argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %% [markdown]
# #### Example

# %% [markdown]
# Set your own size for the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# ## 🔹 **Combine Color Size and Alpha**

# %% [markdown]
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:

# %% [markdown]
# #### Example

# %% [markdown]
# Create random arrays with 100 values for x-points, y-points, colors and sizes:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # **Matplotlib Bars**
# ---

# %% [markdown]
# ## 🔹 **Creating Bars**

# %% [markdown]
# #### Example

# %% [markdown]
# With Pyplot, you can use the `bar()` function to draw bar graphs:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# The `bar()` function takes arguments that describes the layout of the bars.
#
# The categories and their values represented by the first and second argument as arrays.

# %% [markdown]
# #### Example

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x = ["APPLES", "BANANAS"]
y = [400, 350]

plt.bar(x, y)
plt.show()

# %% [markdown]
# ## 🔹 **Horizontal Bars**

# %% [markdown]
# If you want the bars to be displayed horizontally instead of vertically, use the `barh()` function:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 horizontal bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# ## 🔹 **Bar Color**

# %% [markdown]
# The `bar()` and `barh()` take the keyword argument `color` to set the color of the bars:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 red bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %% [markdown]
# ### 🔸  *Color Names*

# %% [markdown]
# You can use any of the [140 supported color names](https://htmlcolorcodes.com/color-names/).

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 "hot pink" bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %% [markdown]
# ### 🔸  *Color Hex*

# %% [markdown]
# Or you can use [Hexadecimal color values](https://htmlcolorcodes.com/):

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 bars with a beautiful green color:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %% [markdown]
# ## 🔹 **Bar Width**

# %% [markdown]
# The `bar()` takes the keyword argument `width` to set the width of the bars:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# The default width value is 0.8

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b>  For horizontal bars, use <code>height</code> instead of <code>width</code>.

# %% [markdown]
# ## 🔹 **Bar Height**

# %% [markdown]
# The `barh()` takes the keyword argument `height` to set the height of the bars:

# %% [markdown]
# #### Example

# %% [markdown]
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b>  The default height value is 0.8

# %% [markdown]
# # **Matplotlib Histograms**
# ---

# %% [markdown]
# ## 🔹 **Histogram**

# %% [markdown]
# * A histogram is a graph showing frequency distributions.
# * It is a graph showing the number of observations within each given interval.
# * **Example:** Say you ask for the height of 250 people, you might end up with a histogram like this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the height intervals (bins)
bins = [140, 145, 150, 156, 162, 168, 173, 178, 184, 190, 195]

# Define the frequencies (number of people in each interval)
frequencies = [2, 5, 15, 31, 46, 53, 45, 28, 21, 4]

# Create the histogram
plt.hist(bins[:-1], bins=bins, weights=frequencies, edgecolor='black', align='left')

# Add labels and title
plt.xlabel('Height (cm)')
plt.ylabel('Number of People')
plt.title('Height Distribution of 250 People')

# Display the plot
plt.show()

# %% [markdown]
# You can read from the histogram that there are approximately:
#
# 2 people from 140 to 145cm<br>
# 5 people from 145 to 150cm<br>
# 15 people from 151 to 156cm<br>
# 31 people from 157 to 162cm<br>
# 46 people from 163 to 168cm<br>
# 53 people from 168 to 173cm<br>
# 45 people from 173 to 178cm<br>
# 28 people from 179 to 184cm<br>
# 21 people from 185 to 190cm<br>
# 4 people from 190 to 195cm<br>

# %% [markdown]
# ## 🔹 **Create Histogram**

# %% [markdown]
# * In Matplotlib, we use the `hist()` function to create histograms.
# * The `hist()` function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
# * For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10.

# %% [markdown]
# #### Example

# %% [markdown]
# A Normal Data Distribution by NumPy:

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [159.22451167 181.76291687 181.02647279 180.87338482 164.66872208
#  183.90654999 180.87991109 162.92566451 183.58946026 147.14733942
#  185.89285502 166.70358241 178.15196699 158.29181999 168.40564509
#  173.98563934 180.49059575 171.7109473  161.58560299 162.94719602
#  166.41379845 174.22392965 169.98707488 154.62101199 173.22401483
#  172.55516067 181.2039055  159.91380597 155.37366079 170.93553869
#  151.46653454 158.85229702 161.28280279 181.11481791 173.75717109
#  176.09402048 162.91659265 192.13331363 184.12887751 166.09149044
#  176.68989034 169.00966793 165.20743597 193.22629528 156.70428127
#  169.05292589 179.99305132 162.67286535 162.65614942 165.96951642
#  158.74464761 172.88492046 175.68777103 162.87242571 164.62243619
#  188.85904995 173.10538827 163.68788411 156.7980511  177.50886545
#  176.23448383 174.09397938 191.93013441 171.37313314 178.8847418
#  172.55200849 174.46073442 162.15249565 202.13345455 157.48581302
# ...

# %% [markdown]
# The `hist()` function will read the array and produce a histogram:

# %% [markdown]
# #### Example

# %% [markdown]
# A simple histogram:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# # **Matplotlib Pie Charts**
# ---

# %% [markdown]
# ## 🔹 **Creating Pie Charts**

# %% [markdown]
# With Pyplot, you can use the `pie()` function to draw pie charts:

# %% [markdown]
# #### Example

# %% [markdown]
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# As you can see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
# By default the plotting of the first wedge starts from the x-axis and moves counterclockwise:

# %% [markdown]
# <div align="center"><img width="600px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# <div class="alert alert-block" style="background-color: #FFD08A; color: black;">
# <b>Note:</b>  The size of each wedge is determined by comparing the value with all the other values, by using this formula:
# <ul>
# <li>The value divided by the sum of all values: x/sum(x)
# </ul>

# %% [markdown]
# ## 🔹 **Label**

# %% [markdown]
# Add labels to the pie chart with the `labels` parameter.
#
# The `labels` parameter must be an array with one label for each wedge:

# %% [markdown]
# #### Example

# %% [markdown]
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## 🔹 **Start Angle**

# %% [markdown]
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a `startangle` parameter.
#
# The `startangle` parameter is defined with an angle in degrees, default angle is 0:

# %% [markdown]
# <div align="center"><img width="600px" style="display:block; margin-left: auto; margin-right: auto;" src="data:image/png;base64,...">

# %% [markdown]
# #### Example

# %% [markdown]
# Start the first wedge at 90 degrees:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# ## 🔹 **Explode**

# %% [markdown]
# * Maybe you want one of the wedges to stand out? The `explode` parameter allows you to do that.
# * The `explode` parameter, if specified, and not `None`, must be an array with one value for each wedge.
# * Each value represents how far from the center each wedge is displayed:

# %% [markdown]
# #### Example

# %% [markdown]
# Pull the "Apples" wedge 0.2 from the center of the pie:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## 🔹 **Shadow**

# %% [markdown]
# Add a `shadow` to the pie chart by setting the shadows parameter to `True`:

# %% [markdown]
# #### Example

# %% [markdown]
# Add a shadow:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## 🔹 **Colors**

# %% [markdown]
# * You can set the color of each wedge with the `colors` parameter.
# * The `colors` parameter, if specified, must be an array with one value for each wedge:

# %% [markdown]
# #### Example

# %% [markdown]
# Specify a new color for each wedge:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# You can use [Hexadecimal](https://htmlcolorcodes.com/) color values, any of the [140 supported color names](https://htmlcolorcodes.com/color-names/), or one of these shortcuts:
# * 'r' - Red
# * 'g' - Green
# * 'b' - Blue
# * 'c' - Cyan
# * 'm' - Magenta
# * 'y' - Yellow
# * 'k' - Black
# * 'w' - White

# %% [markdown]
# ## 🔹 **Legend**

# %% [markdown]
# To add a list of explanation for each wedge, use the `legend()` function:

# %% [markdown]
# #### Example

# %% [markdown]
# Add a legend:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ### 🔸  *Legend With Header*

# %% [markdown]
# To add a header to the legend, add the `title` parameter to the `legend` function.

# %% [markdown]
# #### Example

# %% [markdown]
# Add a legend with a header:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
